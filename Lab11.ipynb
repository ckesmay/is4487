# %% [markdown]
# <a href="https://colab.research.google.com/github/ckesmay/is4487/blob/main/Lab11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 5 Script
#
# ## Objectives
#
# a. Understand model accuracy.  Why is it a performance metric for classification and not regression?
#
# b. Calculate accuracy for a simple majority class model (this is the same as calculating the proportion of the majority class in a binary variable). Consider: x <- c(1, 1, 1, 0, 0).  What is the majority class? What is the proportion of the majority class in x?
#
# c. Fit a tree model of the target with just one predictor variable and calculate the accuracy of this model.
#
# d. Interpret a tree model, and calculate information gain.
#
# e. Fit a tree model of the target using all the predictors, then:  create a visualization of the tree and identify the top 3 most important predictors in this model.
#
# f. How do these models compare to majority class prediction?
#
# g. How will you use a classification model as part of a solution to the AdviseInvest case?
#
# We will use the MegaTelCo data for this demonstration.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

from sklearn.tree import DecisionTreeClassifier, export_graphviz # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/aqi.csv')
# Out:
# Mounted at /content/gdrive

# %%
#look at the top rows
df.head(10)
# Out:
#   State Name county Name  State Code  County Code        Date  AQI  Category  \
# 0    Alabama     Baldwin           1            3  2021-01-01   27      Good
# 1    Alabama     Baldwin           1            3  2021-01-04   47      Good
# 2    Alabama     Baldwin           1            3  2021-01-07   24      Good
# 3    Alabama     Baldwin           1            3  2021-01-10   39      Good
# 4    Alabama     Baldwin           1            3  2021-01-13   46      Good
# 5    Alabama     Baldwin           1            3  2021-01-16   21      Good
# 6    Alabama     Baldwin           1            3  2021-01-19   52  Moderate
# 7    Alabama     Baldwin           1            3  2021-01-22   11      Good
# 8    Alabama     Baldwin           1            3  2021-01-25   39      Good
# 9    Alabama     Baldwin           1            3  2021-01-28   22      Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1
# 5              PM2.5   01-003-0010                          1
# 6              PM2.5   01-003-0010                          1
# 7              PM2.5   01-003-0010                          1
# 8              PM2.5   01-003-0010                          1
# 9              PM2.5   01-003-0010                          1

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218196 entries, 0 to 218195
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State Name                 218196 non-null  object
#  1   county Name                218196 non-null  object
#  2   State Code                 218196 non-null  int64
#  3   County Code                218196 non-null  int64
#  4   Date                       218196 non-null  object
#  5   AQI                        218196 non-null  int64
#  6   Category                   218196 non-null  object
#  7   Defining Parameter         218196 non-null  object
#  8   Defining Site              218196 non-null  object
#  9   Number of Sites Reporting  218196 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 16.6+ MB

# %%
#describe the data before cleaning it
df.describe()
# Out:
#           State Code    County Code            AQI  Number of Sites Reporting
# count  218196.000000  218196.000000  218196.000000              218196.000000
# mean       30.178390      82.098265      39.584250                   1.924220
# std        15.755914      89.555906      21.547055                   2.251967
# min         1.000000       1.000000       0.000000                   1.000000
# 25%        18.000000      25.000000      29.000000                   1.000000
# 50%        30.000000      61.000000      38.000000                   1.000000
# 75%        42.000000     111.000000      47.000000                   2.000000
# max        80.000000     810.000000    2723.000000                  34.000000

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?
#
# Clean up the data in a  new datafram named "df_clean"

# %%
#delete rows with outlier data; put it in a new dataframe
df_clean = df[(df['State Name'] == 'Utah') & (df['county Name'] == 'Salt Lake')]
df_clean['Date']= pd.to_datetime(df_clean['Date'])
#delete any rows with missing values in the clean dataframe
df_clean = df_clean.dropna() 

df_clean.head(50)
# Out:
# <ipython-input-41-52d173f74aa5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Date']= pd.to_datetime(df_clean['Date'])
#        State Name county Name  State Code  County Code       Date  AQI  \
# 193138       Utah   Salt Lake          49           35 2021-01-01   70
# 193139       Utah   Salt Lake          49           35 2021-01-02   48
# 193140       Utah   Salt Lake          49           35 2021-01-03   51
# 193141       Utah   Salt Lake          49           35 2021-01-04   52
# 193142       Utah   Salt Lake          49           35 2021-01-05   37
# 193143       Utah   Salt Lake          49           35 2021-01-06   43
# 193144       Utah   Salt Lake          49           35 2021-01-07   60
# 193145       Utah   Salt Lake          49           35 2021-01-08   66
# 193146       Utah   Salt Lake          49           35 2021-01-09   53
# 193147       Utah   Salt Lake          49           35 2021-01-10   51
# 193148       Utah   Salt Lake          49           35 2021-01-11   72
# 193149       Utah   Salt Lake          49           35 2021-01-12   85
# 193150       Utah   Salt Lake          49           35 2021-01-13   71
# 193151       Utah   Salt Lake          49           35 2021-01-14   52
# 193152       Utah   Salt Lake          49           35 2021-01-15   45
# 193153       Utah   Salt Lake          49           35 2021-01-16   58
# 193154       Utah   Salt Lake          49           35 2021-01-17   58
# 193155       Utah   Salt Lake          49           35 2021-01-18   40
# 193156       Utah   Salt Lake          49           35 2021-01-19   42
# 193157       Utah   Salt Lake          49           35 2021-01-20   50
# 193158       Utah   Salt Lake          49           35 2021-01-21   73
# 193159       Utah   Salt Lake          49           35 2021-01-22   56
# 193160       Utah   Salt Lake          49           35 2021-01-23   36
# 193161       Utah   Salt Lake          49           35 2021-01-24   38
# 193162       Utah   Salt Lake          49           35 2021-01-25   56
# 193163       Utah   Salt Lake          49           35 2021-01-26   46
# 193164       Utah   Salt Lake          49           35 2021-01-27   34
# 193165       Utah   Salt Lake          49           35 2021-01-28   33
# 193166       Utah   Salt Lake          49           35 2021-01-29   36
# 193167       Utah   Salt Lake          49           35 2021-01-30   37
# 193168       Utah   Salt Lake          49           35 2021-01-31   38
# 193169       Utah   Salt Lake          49           35 2021-02-01   60
# 193170       Utah   Salt Lake          49           35 2021-02-02   74
# 193171       Utah   Salt Lake          49           35 2021-02-03   36
# 193172       Utah   Salt Lake          49           35 2021-02-04   52
# 193173       Utah   Salt Lake          49           35 2021-02-05   59
# 193174       Utah   Salt Lake          49           35 2021-02-06   58
# 193175       Utah   Salt Lake          49           35 2021-02-07   42
# 193176       Utah   Salt Lake          49           35 2021-02-08   46
# 193177       Utah   Salt Lake          49           35 2021-02-09   40
# 193178       Utah   Salt Lake          49           35 2021-02-10   41
# 193179       Utah   Salt Lake          49           35 2021-02-11   36
# 193180       Utah   Salt Lake          49           35 2021-02-12   31
# 193181       Utah   Salt Lake          49           35 2021-02-13   33
# 193182       Utah   Salt Lake          49           35 2021-02-14   34
# 193183       Utah   Salt Lake          49           35 2021-02-15   37
# 193184       Utah   Salt Lake          49           35 2021-02-16   36
# 193185       Utah   Salt Lake          49           35 2021-02-17   42
# 193186       Utah   Salt Lake          49           35 2021-02-18   40
# 193187       Utah   Salt Lake          49           35 2021-02-19   39
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting  \
# 193138  Moderate              PM2.5   49-035-4002                          7
# 193139      Good              PM2.5   49-035-3015                          7
# 193140  Moderate              PM2.5   49-035-3015                          7
# 193141  Moderate              PM2.5   49-035-4002                          7
# 193142      Good                NO2   49-035-2005                          7
# 193143      Good                NO2   49-035-3010                          7
# 193144  Moderate              PM2.5   49-035-3015                          7
# 193145  Moderate              PM2.5   49-035-3015                          7
# 193146  Moderate              PM2.5   49-035-3010                          7
# 193147  Moderate              PM2.5   49-035-3010                          7
# 193148  Moderate              PM2.5   49-035-4002                          7
# 193149  Moderate              PM2.5   49-035-4002                          7
# 193150  Moderate              PM2.5   49-035-3015                          7
# 193151  Moderate                NO2   49-035-3015                          7
# 193152      Good                NO2   49-035-3010                          7
# 193153  Moderate              PM2.5   49-035-2005                          7
# 193154  Moderate              PM2.5   49-035-3010                          7
# 193155      Good              PM2.5   49-035-3006                          7
# 193156      Good                NO2   49-035-3010                          7
# 193157      Good              PM2.5   49-035-4002                          7
# 193158  Moderate              PM2.5   49-035-4002                          7
# 193159  Moderate              PM2.5   49-035-4002                          7
# 193160      Good              Ozone   49-035-3013                          7
# 193161      Good              PM2.5   49-035-3013                          7
# 193162  Moderate              PM2.5   49-035-4002                          7
# 193163      Good              PM2.5   49-035-4002                          7
# 193164      Good              Ozone   49-035-3013                          7
# 193165      Good              Ozone   49-035-4002                          7
# 193166      Good              Ozone   49-035-3013                          7
# 193167      Good              Ozone   49-035-3006                          7
# 193168      Good                NO2   49-035-3015                          7
# 193169  Moderate              PM2.5   49-035-3015                          7
# 193170  Moderate              PM2.5   49-035-3010                          7
# 193171      Good              Ozone   49-035-3013                          7
# 193172  Moderate               PM10   49-035-3015                          7
# 193173  Moderate               PM10   49-035-3015                          7
# 193174  Moderate               PM10   49-035-3015                          7
# 193175      Good               PM10   49-035-3015                          7
# 193176      Good                NO2   49-035-3015                          6
# 193177      Good                NO2   49-035-4002                          6
# 193178      Good                NO2   49-035-3006                          7
# 193179      Good                NO2   49-035-3015                          7
# 193180      Good              Ozone   49-035-3013                          7
# 193181      Good              Ozone   49-035-3013                          7
# 193182      Good              Ozone   49-035-3013                          7
# 193183      Good              Ozone   49-035-3013                          7
# 193184      Good              Ozone   49-035-3013                          7
# 193185      Good                NO2   49-035-3015                          7
# 193186      Good                NO2   49-035-3015                          7
# 193187      Good                NO2   49-035-3015                          7
#
#        PM Flag
# 193138    True
# 193139    True
# 193140    True
# 193141    True
# 193142   False
# 193143   False
# 193144    True
# 193145    True
# 193146    True
# 193147    True
# 193148    True
# 193149    True
# 193150    True
# 193151   False
# 193152   False
# 193153    True
# 193154    True
# 193155    True
# 193156   False
# 193157    True
# 193158    True
# 193159    True
# 193160   False
# 193161    True
# 193162    True
# 193163    True
# 193164   False
# 193165   False
# 193166   False
# 193167   False
# 193168   False
# 193169    True
# 193170    True
# 193171   False
# 193172   False
# 193173   False
# 193174   False
# 193175   False
# 193176   False
# 193177   False
# 193178   False
# 193179   False
# 193180   False
# 193181   False
# 193182   False
# 193183   False
# 193184   False
# 193185   False
# 193186   False
# 193187   False

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305 entries, 193138 to 193442
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State Name                 305 non-null    object
#  1   county Name                305 non-null    object
#  2   State Code                 305 non-null    int64
#  3   County Code                305 non-null    int64
#  4   Date                       305 non-null    datetime64[ns]
#  5   AQI                        305 non-null    int64
#  6   Category                   305 non-null    object
#  7   Defining Parameter         305 non-null    object
#  8   Defining Site              305 non-null    object
#  9   Number of Sites Reporting  305 non-null    int64
#  10  PM Flag                    305 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 28.6+ KB

# %%
df_clean['PM Flag'] = df_clean['Defining Parameter']=='PM2.5'
df_clean['NO2 Flag'] = df_clean['Defining Parameter']=='NO2'
df_clean['Ozone Flag'] = df_clean['Defining Parameter']=='Ozone'

# %%
df_clean.head()
# Out:
#        State Name county Name  State Code  County Code       Date  AQI  \
# 193138       Utah   Salt Lake          49           35 2021-01-01   70
# 193139       Utah   Salt Lake          49           35 2021-01-02   48
# 193140       Utah   Salt Lake          49           35 2021-01-03   51
# 193141       Utah   Salt Lake          49           35 2021-01-04   52
# 193142       Utah   Salt Lake          49           35 2021-01-05   37
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting  \
# 193138  Moderate              PM2.5   49-035-4002                          7
# 193139      Good              PM2.5   49-035-3015                          7
# 193140  Moderate              PM2.5   49-035-3015                          7
# 193141  Moderate              PM2.5   49-035-4002                          7
# 193142      Good                NO2   49-035-2005                          7
#
#         PM Flag  NO2 Flag  Ozone Flag
# 193138     True     False       False
# 193139     True     False       False
# 193140     True     False       False
# 193141     True     False       False
# 193142    False      True       False

# %%
# split the datafram into independent (x) and dependent (predicted) attributes (y)
x = df_clean[['AQI','PM Flag', 'NO2 Flag', 'Ozone Flag']]
y = df_clean['Category']

money_tree = DecisionTreeClassifier(criterion="entropy", max_depth = 10)

# Create Decision Tree Classifer
money_tree = money_tree.fit(x,y)

# %% [markdown]
# ## Preview the tree

# %%
money_tree_text = tree.export_text(money_tree)
print(money_tree_text)
# Out:
# |--- feature_0 <= 50.50
# |   |--- class: Good
# |--- feature_0 >  50.50
# |   |--- feature_0 <= 100.50
# |   |   |--- class: Moderate
# |   |--- feature_0 >  100.50
# |   |   |--- feature_0 <= 150.50
# |   |   |   |--- class: Unhealthy for Sensitive Groups
# |   |   |--- feature_0 >  150.50
# |   |   |   |--- class: Unhealthy

# %% [markdown]
# ## Check Accuracy
#
# What is the accuracy of the money_tree? Use these steps to calculate accuracy.
#
# Is this over fitted?

# %%
pred = money_tree.predict(x)

#print(pred)

print("Accuracy:",metrics.accuracy_score(y, pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# ## Prune the tree
#
# Limit the number of levels to 2

# %%
money_tree2 = DecisionTreeClassifier(criterion="entropy", max_depth=10)

# Create Decision Tree Classifer
money_tree2 = money_tree2.fit(x,y)

# %% [markdown]
# ## Preview the new tree

# %%
money_tree2_text = tree.export_text(money_tree2)
print(money_tree2_text)
# Out:
# |--- feature_0 <= 50.50
# |   |--- class: Good
# |--- feature_0 >  50.50
# |   |--- feature_0 <= 100.50
# |   |   |--- class: Moderate
# |   |--- feature_0 >  100.50
# |   |   |--- feature_0 <= 150.50
# |   |   |   |--- class: Unhealthy for Sensitive Groups
# |   |   |--- feature_0 >  150.50
# |   |   |   |--- class: Unhealthy

# %% [markdown]
# ## Re-Check Accuracy
#
# Is this accuracy better than making a random guess?  (check the distribution above)

# %%
pred = money_tree2.predict(x)

print("Accuracy:",metrics.accuracy_score(y, pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# ## Visualize the model

# %%
from six import StringIO
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(money_tree2, out_file=dot_data, 
                   feature_names=x.columns,class_names=['Good','Moderate', 'Unhealthy'], 
                   filled=True,rounded=True, precision =2)

graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-96990312bb4a> in <cell line: 6>()
#       4
#       5 dot_data = StringIO()
# ----> 6 export_graphviz(money_tree2, out_file=dot_data,
#       7                    feature_names=x.columns,class_names=['leave','stay'],
#       8                    filled=True,rounded=True, precision =2)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision, fontname)
#     886             fontname=fontname,
#     887         )
# --> 888         exporter.export(decision_tree)
#     889
#     890         if return_string:
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in export(self, decision_tree)
#     459             self.recurse(decision_tree, 0, criterion="impurity")
#     460         else:
# --> 461             self.recurse(decision_tree.tree_, 0, criterion=decision_tree.criterion)
#     462
#     463         self.tail()
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     548                     depth=depth + 1,
#     549                 )
# --> 550                 self.recurse(
#     551                     tree,
#     552                     right_child,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     548                     depth=depth + 1,
#     549                 )
# --> 550                 self.recurse(
#     551                     tree,
#     552                     right_child,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in recurse(self, tree, node_id, criterion, parent, depth)
#     518
#     519             self.out_file.write(
# --> 520                 "%d [label=%s" % (node_id, self.node_to_str(tree, node_id, criterion))
#     521             )
#     522
#
# /usr/local/lib/python3.9/dist-packages/sklearn/tree/_export.py in node_to_str(self, tree, node_id, criterion)
#     364                 node_string += "class = "
#     365             if self.class_names is not True:
# --> 366                 class_name = self.class_names[np.argmax(value)]
#     367             else:
#     368                 class_name = "y%s%s%s" % (
#
# IndexError: list index out of range

# %% [markdown]
# ## Fit a full tree model
#
# Use all of the independent attributes.  We'll call this the "full tree."
#
# What is the accuracy of the full tree?

# %% [markdown]
# ##Visualize the full tree
