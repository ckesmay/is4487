# %% [markdown]
# <a href="https://colab.research.google.com/github/ckesmay/is4487/blob/main/Module2_Script_v1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/retail_dataset.csv')

print (df)
# Out:
# Mounted at /content/gdrive
#       customer_id      customer_name          address_line_1          city  \
# 0              67      Gordy Matteau     59 Northland Circle    Wilmington
# 1             201     Cort Paskerful         769 Buell Drive    Huntsville
# 2              45    Willetta Lumley       41 Ridgeway Alley        Irvine
# 3             106   Alison Batterton           489 Erie Hill      Richmond
# 4             357  Martelle Paxeford    451 Manitowish Place      Richmond
# ...           ...                ...                     ...           ...
# 9564          637  Jayson Andriessen  0819 Crownhardt Circle     Allentown
# 9565          370    Darby Tesseyman     7468 Jackson Circle        Albany
# 9566          598   Henka De Ferrari      89 Sunnyside Drive  Redwood City
# 9567          737    Tommie Penvarne    9630 Washington Hill     Watertown
# 9568          482       Matelda Bull      6406 Bultman Alley  Gaithersburg
#
# ...

# %%
#look at the top rows
df.head(10)
# Out:
#    customer_id      customer_name        address_line_1        city  \
# 0           67      Gordy Matteau   59 Northland Circle  Wilmington
# 1          201     Cort Paskerful       769 Buell Drive  Huntsville
# 2           45    Willetta Lumley     41 Ridgeway Alley      Irvine
# 3          106   Alison Batterton         489 Erie Hill    Richmond
# 4          357  Martelle Paxeford  451 Manitowish Place    Richmond
# 5          351      Glenn Reville    3 Springview Drive      Dallas
# 6          233  Cosette Berkowitz       7619 Susan Lane  South Bend
# 7          121      Nisse Cunniam         0 Dennis Pass     Lincoln
# 8          232         Yank Eayrs       8176 Lawn Drive  Washington
# 9          113   Jamesy Brothwood   0693 Evergreen Pass    Scranton
#
#               state_province  postal_code  order_id  order_date  \
# 0  DE                             19805.0      1001  2020-01-11
# 1  AL                             35810.0      1002  2019-11-22
# ...

# %%
#look at last rows
df.tail(10)
# Out:
#       customer_id      customer_name           address_line_1  \
# 9559          311     Ardella Lynagh  5092 Summer Ridge Court
# 9560           30    Mano Swanborrow       1845 Waywood Alley
# 9561          240     Barnard Hatley           5541 Kim Alley
# 9562          782      Edmund Hugues        814 Scott Terrace
# 9563          722    Marwin Darrigoe        22 South Crossing
# 9564          637  Jayson Andriessen   0819 Crownhardt Circle
# 9565          370    Darby Tesseyman      7468 Jackson Circle
# 9566          598   Henka De Ferrari       89 Sunnyside Drive
# 9567          737    Tommie Penvarne     9630 Washington Hill
# 9568          482       Matelda Bull       6406 Bultman Alley
#
#                   city             state_province  postal_code  order_id  \
# 9559             Tulsa  OK                             74116.0      8138
# 9560  Saint Petersburg  FL                             33737.0      8139
# ...

# %%
#get a summary of the dataset
df.describe()
# Out:
#        customer_id   postal_code     order_id  customer_id.1   order_id.1  \
# count  9569.000000   9416.000000  9569.000000    9569.000000  9569.000000
# mean    282.910962  52225.007116  5107.539450     282.910962  5107.539450
# std     199.763947  29619.544418  2043.449403     199.763947  2043.449403
# min       1.000000   1105.000000  1001.000000       1.000000  1001.000000
# 25%     127.000000  27409.000000  3393.000000     127.000000  3393.000000
# 50%     253.000000  48295.000000  5577.000000     253.000000  5577.000000
# 75%     376.000000  79923.000000  6829.000000     376.000000  6829.000000
# max     800.000000  99812.000000  8147.000000     800.000000  8147.000000
#
#         product_id     quantity  product_id.1
# count  9569.000000  9513.000000   9569.000000
# mean    106.736650     3.453380    106.736650
# std       3.694805     4.393894      3.694805
# min     101.000000     1.000000    101.000000
# 25%     104.000000     1.000000    104.000000
# ...

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9569 entries, 0 to 9568
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       9569 non-null   int64
#  1   customer_name     9569 non-null   object
#  2   address_line_1    9448 non-null   object
#  3   city              9516 non-null   object
#  4   state_province    9569 non-null   object
#  5   postal_code       9416 non-null   float64
#  6   order_id          9569 non-null   int64
#  7   order_date        9312 non-null   object
#  8   customer_id.1     9569 non-null   int64
#  9   order_id.1        9569 non-null   int64
#  10  product_id        9569 non-null   int64
#  11  quantity          9513 non-null   float64
#  12  product_id.1      9569 non-null   int64
#  13  product_name      9569 non-null   object
#  14  product_price     9569 non-null   object
#  15  total_amount      9513 non-null   object
# ...

# %% [markdown]
# ## Clean up the data
# Strip dollar signs and commas from total amount column.

# %%
df['total_amount']=df['total_amount'].str.replace('$','')
df['total_amount']=df['total_amount'].str.replace(',','')

df.head()
# Out:
# <ipython-input-35-8cb24650a6e0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['total_amount']=df['total_amount'].str.replace('$','')
#    customer_id      customer_name        address_line_1        city  \
# 0           67      Gordy Matteau   59 Northland Circle  Wilmington
# 1          201     Cort Paskerful       769 Buell Drive  Huntsville
# 2           45    Willetta Lumley     41 Ridgeway Alley      Irvine
# 3          106   Alison Batterton         489 Erie Hill    Richmond
# 4          357  Martelle Paxeford  451 Manitowish Place    Richmond
#
#               state_province  postal_code  order_id  order_date  \
# 0  DE                             19805.0      1001  2020-01-11
# 1  AL                             35810.0      1002  2019-11-22
# 2  CA                             92612.0      1003  2019-09-17
# ...

# %% [markdown]
# Change total amount column from string to float

# %%
df['total_amount']=df['total_amount'].astype(float)
df.head()
# Out:
#    customer_id      customer_name        address_line_1        city  \
# 0           67      Gordy Matteau   59 Northland Circle  Wilmington
# 1          201     Cort Paskerful       769 Buell Drive  Huntsville
# 2           45    Willetta Lumley     41 Ridgeway Alley      Irvine
# 3          106   Alison Batterton         489 Erie Hill    Richmond
# 4          357  Martelle Paxeford  451 Manitowish Place    Richmond
#
#               state_province  postal_code  order_id  order_date  \
# 0  DE                             19805.0      1001  2020-01-11
# 1  AL                             35810.0      1002  2019-11-22
# 2  CA                             92612.0      1003  2019-09-17
# 3  VA                             23293.0      1004  2019-12-09
# 4  VA                             23293.0      1005  2019-06-08
#
#    customer_id.1  order_id.1  product_id  quantity  product_id.1  \
# 0             67        1001         106       3.0           106
# ...

# %% [markdown]
# Drops rows with null values

# %%
df = df.dropna(subset = ['quantity', 'total_amount'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9513 entries, 0 to 9568
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       9513 non-null   int64
#  1   customer_name     9513 non-null   object
#  2   address_line_1    9397 non-null   object
#  3   city              9460 non-null   object
#  4   state_province    9513 non-null   object
#  5   postal_code       9362 non-null   float64
#  6   order_id          9513 non-null   int64
#  7   order_date        9261 non-null   object
#  8   customer_id.1     9513 non-null   int64
#  9   order_id.1        9513 non-null   int64
#  10  product_id        9513 non-null   int64
#  11  quantity          9513 non-null   float64
#  12  product_id.1      9513 non-null   int64
#  13  product_name      9513 non-null   object
#  14  product_price     9513 non-null   object
#  15  total_amount      9513 non-null   float64
# ...

# %% [markdown]
# Dropping ID because it is not used to extract insights.

# %%
df['product_price']=df['product_price'].str.replace('$','')
df['product_price']=df['product_price'].str.replace(',','')
df['product_price']=df['product_price'].astype(float)

df.head()
# Out:
# <ipython-input-42-b3ca81821e54>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['product_price']=df['product_price'].str.replace('$','')
#    customer_id      customer_name        address_line_1        city  \
# 0           67      Gordy Matteau   59 Northland Circle  Wilmington
# 1          201     Cort Paskerful       769 Buell Drive  Huntsville
# 2           45    Willetta Lumley     41 Ridgeway Alley      Irvine
# 3          106   Alison Batterton         489 Erie Hill    Richmond
# 4          357  Martelle Paxeford  451 Manitowish Place    Richmond
#
#               state_province  postal_code  order_id  order_date  \
# 0  DE                             19805.0      1001  2020-01-11
# 1  AL                             35810.0      1002  2019-11-22
# 2  CA                             92612.0      1003  2019-09-17
# ...

# %%
df['state_province']=df['state_province'].str.replace('NewYork','New York')
df['state_province'].unique()
# Out:
# array(['DE                       ', 'AL                       ',
#        'CA                       ', 'VA                       ',
#        'TX                       ', 'IN                       ',
#        'NE                       ', 'DC                       ',
#        'PA                       ', 'IA                       ',
#        'MO                       ', 'LA                       ',
#        'AK                       ', 'MN                       ',
#        'TN                       ', 'NC                       ',
#        'NV                       ', 'CT                       ',
#        'MI                       ', 'NY                       ',
#        'CO                       ', 'FL                       ',
#        'AZ                       ', 'SC                       ',
#        'ND                       ', 'NM                       ',
#        'MS                       ', 'OH                       ',
# ...

# %%
# Out:
#       customer_id      customer_name        address_line_1         city  \
# 0              67      Gordy Matteau   59 Northland Circle   Wilmington
# 1             201     Cort Paskerful       769 Buell Drive   Huntsville
# 2              45    Willetta Lumley     41 Ridgeway Alley       Irvine
# 3             106   Alison Batterton         489 Erie Hill     Richmond
# 4             357  Martelle Paxeford  451 Manitowish Place     Richmond
# ...           ...                ...                   ...          ...
# 6706          524        Jock Lannin    45 Saint Paul Hill        Miami
# 6707          438  Evangelin Piddock    4 Caliangt Parkway    Riverside
# 6710           74   Kristal Trafford     25899 Ilene Plaza       Fresno
# 6711          434  Friedrick Lydiatt      922 Sommers Road  Albuquerque
# 6723          634       Rodie Nestor  3190 Macpherson Lane     Syracuse
#
#                  state_province  postal_code  order_id  order_date  \
# ...

# %%
df['product_price'].hist(bins =30)
